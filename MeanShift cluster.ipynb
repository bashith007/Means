# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("Mall_customers.csv")
dataset
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
x = dataset.iloc[:,[3,4]].values

# %%
from sklearn.cluster import MeanShift
list1=[]
for i in range(1, 11):
    clustering = MeanShift(bandwidth=i,min_bin_freq=2,max_iter=250)
    clustering.fit(x)
    list1.append(clustering.labels_)
plt.plot(range(1, 11), list1)
plt.title("the Elbow Method")
plt.xlabel("Number of clusters")
plt.ylabel("WCSS")
plt.show()

# %%
from sklearn.cluster import MeanShift
clustering = MeanShift(bandwidth=3,min_bin_freq=2,max_iter=300)
y_clustering = clustering.fit_predict(x)
y_clustering
# Out:
# array([ 44, 104,  42,  43,  44,  43,  42, 103, 102, 101,  23, 100,  23,
#         41,  23,  41,  40,  99,  98,  97,  40,  39,  96,  39,  95,  93,
#         38,  94,  38,  92,  37,  91,  37,  88,  90,  89,  87,  86,  36,
#         85,  35,  84,  35,  83,  36,  82,  80,  81,  34,  34,  22,  33,
#         22,  33,  81,  79,  22,  16,  22,  16,  15,  15,   2,  21,   2,
#         21,   2,   2,  21,  16,  15,  78,   2,  15,  14,   3,   3,  14,
#          3,   7,  14,   3,   7,   7,   3,   7,  20,   3,  20,   7,  13,
#          1,   0,   1,   1,   6,   0,   0,   1,   0,   1,   0,  19,  13,
#         13,   1,   6,   0,   1,   0,   6,  13,   5,   0,   0,   6,   5,
#         19,   5,  12,  12,   5,  12,  77,  76,   4,  32,  75,  11,   4,
#         11,   4,  32,   4,  18,  74,  18,   4,  11,   4,  18,  73,  72,
#         10,  71,  70,  29,   9,  17,  10,  30,  10,  17,   9,  30,  10,
#         31,   9,  31,   9,  29,  69,  68,  67,  28,  27,  66,  65,  28,
# ...

# %%
supervised=pd.DataFrame(dataset)

# %%
supervised["Cluster_group"]=y_clustering
supervised
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
#      Cluster_group
# 0               44
# 1              104
# 2               42
# ...

# %%
supervised.to_csv("mscluster.csv",index=False)

# %%
centroids=clustering.cluster_centers_
centroids
# Out:
# array([[ 62.1       ,  48.1       ],
#        [ 61.375     ,  41.625     ],
#        [ 47.85714286,  49.71428571],
#        [ 54.5       ,  54.33333333],
#        [ 72.2       ,  73.2       ],
#        [ 65.2       ,  42.2       ],
#        [ 62.8       ,  51.6       ],
#        [ 54.        ,  44.        ],
#        [ 87.5       ,  12.75      ],
#        [ 77.75      ,  75.25      ],
#        [ 77.5       ,  88.5       ],
#        [ 72.25      ,   9.25      ],
#        [ 67.        ,  57.5       ],
#        [ 61.5       ,  55.        ],
#        [ 54.        ,  48.        ],
#        [ 47.75      ,  55.5       ],
#        [ 46.5       ,  46.75      ],
#        [ 78.        ,  19.66666667],
#        [ 73.66666667,   5.66666667],
#        [ 63.        ,  58.        ],
#        [ 57.33333333,  57.66666667],
#        [ 47.66666667,  59.        ],
#        [ 44.        ,  51.        ],
#        [ 19.66666667,  14.        ],
#        [102.        ,  68.5       ],
# ...

# %%
y_clustering
# Out:
# array([ 44, 104,  42,  43,  44,  43,  42, 103, 102, 101,  23, 100,  23,
#         41,  23,  41,  40,  99,  98,  97,  40,  39,  96,  39,  95,  93,
#         38,  94,  38,  92,  37,  91,  37,  88,  90,  89,  87,  86,  36,
#         85,  35,  84,  35,  83,  36,  82,  80,  81,  34,  34,  22,  33,
#         22,  33,  81,  79,  22,  16,  22,  16,  15,  15,   2,  21,   2,
#         21,   2,   2,  21,  16,  15,  78,   2,  15,  14,   3,   3,  14,
#          3,   7,  14,   3,   7,   7,   3,   7,  20,   3,  20,   7,  13,
#          1,   0,   1,   1,   6,   0,   0,   1,   0,   1,   0,  19,  13,
#         13,   1,   6,   0,   1,   0,   6,  13,   5,   0,   0,   6,   5,
#         19,   5,  12,  12,   5,  12,  77,  76,   4,  32,  75,  11,   4,
#         11,   4,  32,   4,  18,  74,  18,   4,  11,   4,  18,  73,  72,
#         10,  71,  70,  29,   9,  17,  10,  30,  10,  17,   9,  30,  10,
#         31,   9,  31,   9,  29,  69,  68,  67,  28,  27,  66,  65,  28,
# ...

# %%
import seaborn as sns
facet = sns.lmplot(data=supervised, x=supervised.columns[3],y=supervised.columns[4], hue=supervised.columns[5],
                  fit_reg=False, legend=True, legend_out=True)
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\regression.py:592: UserWarning: legend_out is deprecated from the `lmplot` function signature. Please update your code to pass it using `facet_kws`.
#   warnings.warn(msg, UserWarning)
